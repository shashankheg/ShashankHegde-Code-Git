# %% [markdown]
# # Import library

# %%
import requests 
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %% [markdown]
# # Now assign the URL

# %%
url1='https://floridapoly.edu/directory/index.php'

# %% [markdown]
# # Fetch the raw HTML content from the URL.

# %%
Raw_data = urlopen(url1)
Sample_page = Raw_data.read()

# %%
Sample_page
# Out:
# b'<!DOCTYPE HTML><html lang="en">\n   <head>\n      <meta charset="UTF-8">\n      <meta http-equiv="x-ua-compatible" content="ie=edge">\n      <title>Faculty and Staff Directory</title>\n      <link rel="canonical" href="https://floridapoly.edu/directory/index.php">\n      <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n      <!-- OU Search Ignore Start Here -->\n\n\n\n\n  <link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css"/>\n  <link rel="stylesheet" href="/_resources/css/main.css#2021-03-02">\n  <!-- OmniUpdate developer stylesheet -->\n  <!-- <link rel="stylesheet" href="/_resources/css/omniupdate.css"> -->\n  <!-- Custom CMS stylesheet -->\n  <link rel="stylesheet" href="/_resources/css/custom.css">\n  <link rel="apple-touch-icon" sizes="180x180" href="/_resources/assets/favicon/apple-touch-icon.png">\n  <link rel="icon" type="image/png" sizes="32x32" href="/_resources/assets/favicon/fav
# ...

# %% [markdown]
# #  The HTML content of the webpages can be parsed and scraped with Beautiful Soup

# %%
# Now that the content is ready, iterate
# through the content using BeautifulSoup
html = bs(Sample_page,'html.parser')

# %% [markdown]
# # Show html format using  Beautiful Soup

# %%
html
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Faculty and Staff Directory</title>
# <link href="https://floridapoly.edu/directory/index.php" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!-- OU Search Ignore Start Here -->
# <link href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css" rel="stylesheet" type="text/css">
# <link href="/_resources/css/main.css#2021-03-02" rel="stylesheet"/>
# <!-- OmniUpdate developer stylesheet -->
# <!-- <link rel="stylesheet" href="/_resources/css/omniupdate.css"> -->
# <!-- Custom CMS stylesheet -->
# <link href="/_resources/css/custom.css" rel="stylesheet"/>
# <link href="/_resources/assets/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/_resources/assets/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# ...

# %% [markdown]
# # similarly to get all the occurrences of agiven tag table  Tag

# %%
Table_ = html.find_all('table')
Table_
# Out:
# [<table class="directory-table" id="directory-table">
#  <thead>
#  <tr>
#  <th>NAME &amp; TITLE</th>
#  <th class="select">DEPARTMENT</th>
#  <th>EMAIL</th>
#  <th>PHONE</th>
#  <th class="select">LOCATION</th>
#  <th>OFFICE</th>
#  </tr>
#  </thead>
# ...

# %% [markdown]
# # You table body in find tr tag

# %%
table1=Table_[0].tbody.find_all('tr')
table1[0] # sample show data
# Out:
# <tr data-type="staff"> <td> <h2><a href="/directory/staff/scott-reinhart.php">Scott Reinhart</a></h2> <strong>Staff | Laboratory Technician</strong> </td> <td class="select" data-search="Engineering Physics">		Engineering Physics	</td> <td> <a href="mailto:sreinhart@floridapoly.edu">sreinhart@floridapoly.edu</a> </td> <td> <a href="tel:+1(863)8748878">863-874-8878</a> </td> <td>		Main Campus	</td> <td class="select">		IST-1051A	</td></tr>

# %%
name1=[i.text.strip() for i in table1] #You can get tha table details
Content=[i.replace('\t','') for i in name1] #Replace tabs 
Text=[i.replace('|',"").split() for i in Content]
name_list=[i[:2] for i in Text]
#print(name_list)
Merged_data = [first_name + ' ' + last_name for first_name, last_name in name_list] 
#print(name_list)
Merged_data[:8]
# Out:
# ['Scott Reinhart',
#  'Ala Alnaser',
#  'Mustapha Achoubane',
#  'Ercan Elibol',
#  'Regina Siewert',
#  'Kim Kennedy',
#  'Feng-Jen Yang',
#  'Danny Houser']

# %% [markdown]
# # Table Department

# %%
table1 = table[0].tbody.find_all('td',{'select','data-search'})[::2]
#table1
dpt = [i.text.replace('\t','') for i in table1]
dpt
# Out:
# ['Engineering Physics',
#  'Applied Mathematics',
#  'Office of the President',
#  'Department of Technology Services, Computer Science',
#  'Office of the University Controller',
#  'Office of Advancement',
#  'Computer Science',
#  'University Police Department',
#  'University Police Department',
#  'Business Analytics',
#  'Arts, Humanities and Social Sciences',
#  'Office of the President',
#  'Arts, Humanities and Social Sciences',
#  'Applied Mathematics',
#  'Department of Human Resources',
#  'Department of Student Affairs',
#  'Engineering Physics',
#  'Office of Admissions and Financial Aid',
#  'FIPR',
#  'FIPR',
#  'FIPR',
#  'FIPR',
#  'FIPR',
#  'Office of the University Controller',
#  'Data Science',
#  'Department of Technology Services',
#  'Department of Academic Affairs, Business Analytics, Data Science',
#  'University Police Department',
#  'Computer Science',
#  'Mechanical Engineering',
#  'Mechanical Engineering',
#  'Computer Science',
# ...

# %% [markdown]
# # Table Number and mail Id

# %%
dpt1 = table[0].tbody.find_all('a')
mail = [i.text for i in dpt1]
mail
# Out:
# ['Scott Reinhart',
#  'sreinhart@floridapoly.edu',
#  '863-874-8878',
#  'Ala Alnaser',
#  'aalnaser@floridapoly.edu',
#  '863-874-8531',
#  'Mustapha Achoubane',
#  'machoubane@floridapoly.edu',
#  '863-874-8620',
#  'Ercan Elibol',
#  'eelibol@floridapoly.edu',
#  '863-874-8835',
#  'Regina Siewert',
#  'rsiewert@floridapoly.edu',
#  '863-874-8409',
#  'Kim Kennedy',
#  'kskennedy@floridapoly.edu',
#  '863-874-8514',
#  'Feng-Jen Yang',
#  'fyang@floridapoly.edu',
#  '863-874-8522',
#  'Danny Houser',
#  'jhouser@floridapoly.edu',
#  '863-874-8473',
#  'David Last',
#  'dlast@floridapoly.edu',
#  '863-874-8465',
#  'James Dewey',
#  'jdewey@floridapoly.edu',
#  '863-874-8525',
#  'Patrick Luck',
#  'pluck@floridapoly.edu',
#  '863-874-8511',
#  'ravent@floridapoly.edu',
#  '863-874-8612',
#  'C. Wylie Lenz',
#  'clenz@floridapoly.edu',
#  '863-874-8565',
#  'Jared Bunn',
#  'jbunn@floridapoly.edu',
#  '863-874-8515',
#  'Gloria Nelson',
#  'gnelson@floridapoly.edu',
# ...

# %% [markdown]
# # Remove name from the data

# %%
mail1=[i for i in mail if i not in Merged_data]
mail1
# Out:
# ['sreinhart@floridapoly.edu',
#  '863-874-8878',
#  'aalnaser@floridapoly.edu',
#  '863-874-8531',
#  'machoubane@floridapoly.edu',
#  '863-874-8620',
#  'eelibol@floridapoly.edu',
#  '863-874-8835',
#  'rsiewert@floridapoly.edu',
#  '863-874-8409',
#  'kskennedy@floridapoly.edu',
#  '863-874-8514',
#  'fyang@floridapoly.edu',
#  '863-874-8522',
#  'jhouser@floridapoly.edu',
#  '863-874-8473',
#  'dlast@floridapoly.edu',
#  '863-874-8465',
#  'jdewey@floridapoly.edu',
#  '863-874-8525',
#  'pluck@floridapoly.edu',
#  '863-874-8511',
#  'ravent@floridapoly.edu',
#  '863-874-8612',
#  'C. Wylie Lenz',
#  'clenz@floridapoly.edu',
#  '863-874-8565',
#  'jbunn@floridapoly.edu',
#  '863-874-8515',
#  'gnelson@floridapoly.edu',
#  '863-874-8402',
#  'kmiller@floridapoly.edu',
#  '863-874-8640',
#  'ssrinivasan@floridapoly.edu',
#  '863-874-8527',
#  'mwilliams@floridapoly.edu',
#  '863-874-8629',
#  'jzhang@floridapoly.edu',
#  '863-333-0807',
#  'mwilmot@floridapoly.edu',
# ...

# %% [markdown]
# # Replace empty data with Zero

# %%
filled_data = ['0000' if value == '' else value for value in mail1]
filled_data
# Out:
# ['sreinhart@floridapoly.edu',
#  '863-874-8878',
#  'aalnaser@floridapoly.edu',
#  '863-874-8531',
#  'machoubane@floridapoly.edu',
#  '863-874-8620',
#  'eelibol@floridapoly.edu',
#  '863-874-8835',
#  'rsiewert@floridapoly.edu',
#  '863-874-8409',
#  'kskennedy@floridapoly.edu',
#  '863-874-8514',
#  'fyang@floridapoly.edu',
#  '863-874-8522',
#  'jhouser@floridapoly.edu',
#  '863-874-8473',
#  'dlast@floridapoly.edu',
#  '863-874-8465',
#  'jdewey@floridapoly.edu',
#  '863-874-8525',
#  'pluck@floridapoly.edu',
#  '863-874-8511',
#  'ravent@floridapoly.edu',
#  '863-874-8612',
#  'C. Wylie Lenz',
#  'clenz@floridapoly.edu',
#  '863-874-8565',
#  'jbunn@floridapoly.edu',
#  '863-874-8515',
#  'gnelson@floridapoly.edu',
#  '863-874-8402',
#  'kmiller@floridapoly.edu',
#  '863-874-8640',
#  'ssrinivasan@floridapoly.edu',
#  '863-874-8527',
#  'mwilliams@floridapoly.edu',
#  '863-874-8629',
#  'jzhang@floridapoly.edu',
#  '863-333-0807',
#  'mwilmot@floridapoly.edu',
# ...

# %% [markdown]
# # Remove again missing name

# %%
no_list=['Mazin Al Hamando',
'Ranses Alfonso Rodriguez',
'C. Wylie Lenz','Md Selim Habib',
'Mohammad Reza Khalghani',
'Vijaya Sista Venkata','Musa Norouzian Reykandeh',
'Parisa Darbari Kozekanan','Tommie Lee Jackson III','Samuel de Oliveira',]

# %%
dpt_mail_list=[i for i in filled_data if i not in no_list]

# %% [markdown]
# # Split the data of mail id only

# %%
mail_id=dpt_mail_list[::2]
mail_id[:5] # sample show
# Out:
# ['sreinhart@floridapoly.edu',
#  'aalnaser@floridapoly.edu',
#  'machoubane@floridapoly.edu',
#  'eelibol@floridapoly.edu',
#  'rsiewert@floridapoly.edu']

# %% [markdown]
# # Split the data of number only

# %%
number=[i for i in dpt_mail_list if i not in mail_id]

# %%
number[:5]
# Out:
# ['863-874-8878',
#  '863-874-8531',
#  '863-874-8620',
#  '863-874-8835',
#  '863-874-8409']

# %% [markdown]
# # Create data frame Name and Mail id and Department

# %%
import pandas as pd

# %%
df_num=pd.DataFrame(number)

# %%
df_mail=pd.DataFrame(mail_id)

# %%
df_dpt=pd.DataFrame(dpt)

# %%
df_name=pd.DataFrame(merged_data)

# %%
FINALL_data=pd.concat([df_name,df_dpt,df_mail,df_num],axis=1)

# %% [markdown]
# # Finally all  Data to CSV file change to use pandas to_csv

# %%
FINALL_data.to_csv('Florida_Polytechnic_University.csv')
